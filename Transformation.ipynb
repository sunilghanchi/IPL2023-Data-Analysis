# %%
import pandas as pd

# %%
df1 = pd.read_csv("D:\Data Analysis\Projects\IPL2023\data\IPLdata.csv")

# %%
df1
# Out:
#     Match_Id        Team 1       Team 2                      Team  \
# 0          1        Titans  Super Kings     Titans Vs Super Kings
# 1          2  Punjab Kings          KKR       Punjab Kings Vs KKR
# 2          3  Super Giants     Capitals  Super Giants Vs Capitals
# 3          4     Sunrisers       Royals       Sunrisers Vs Royals
# 4          5           RCB       Mumbai             RCB Vs Mumbai
# ..       ...           ...          ...                       ...
# 69        70           RCB       Titans             RCB Vs Titans
# 70        71   Super Kings       Titans     Super Kings Vs Titans
# 71        72  Super Giants       Mumbai    Super Giants Vs Mumbai
# 72        73        Titans       Mumbai          Titans Vs Mumbai
# 73        74        Titans  Super Kings     Titans Vs Super Kings
#
#           Winner     Margin     Ground             Date  \
# 0         Titans  5 wickets  Ahmedabad     Mar 31, 2023
# 1   Punjab Kings     7 runs     Mohali      Apr 1, 2023
# ...

# %%
teams = {
    "Titans":'Gujarat Titans',
    "Super Kings":'Chennai Super Kings',
    "Punjab Kings":'Punjab Kings',
    "KKR":'Kolkata Knight Riders',
    "Super Giants":'Lucknow Super Giants',
    "Capitals":'Delhi Capitals',
    "Sunrisers":'Sunrisers Hyderabad',
    "Royals":'Rajasthan Royals',
    "RCB":'Royal Challengers Bangalore',
    "Mumbai":'Mumbai Indians',
}

# %%
df1['Team 1'] = df1['Team 1'].map(teams)
df1['Team 2'] = df1['Team 2'].map(teams)

# %%
df1['Winner'] = df1['Winner'].map(teams)

# %%
df1.drop('Team', axis=1)
# Out:
#     Match_Id                       Team 1                 Team 2  \
# 0          1               Gujarat Titans    Chennai Super Kings
# 1          2                 Punjab Kings  Kolkata Knight Riders
# 2          3         Lucknow Super Giants         Delhi Capitals
# 3          4          Sunrisers Hyderabad       Rajasthan Royals
# 4          5  Royal Challengers Bangalore         Mumbai Indians
# ..       ...                          ...                    ...
# 69        70  Royal Challengers Bangalore         Gujarat Titans
# 70        71          Chennai Super Kings         Gujarat Titans
# 71        72         Lucknow Super Giants         Mumbai Indians
# 72        73               Gujarat Titans         Mumbai Indians
# 73        74               Gujarat Titans    Chennai Super Kings
#
#                          Winner     Margin     Ground             Date  \
# 0                Gujarat Titans  5 wickets  Ahmedabad     Mar 31, 2023
# ...

# %%
df1['Team'] = df1['Team 1']+' Vs '+ df1['Team 2']

# %%
df1
# Out:
#     Match_Id                       Team 1                 Team 2  \
# 0          1               Gujarat Titans    Chennai Super Kings
# 1          2                 Punjab Kings  Kolkata Knight Riders
# 2          3         Lucknow Super Giants         Delhi Capitals
# 3          4          Sunrisers Hyderabad       Rajasthan Royals
# 4          5  Royal Challengers Bangalore         Mumbai Indians
# ..       ...                          ...                    ...
# 69        70  Royal Challengers Bangalore         Gujarat Titans
# 70        71          Chennai Super Kings         Gujarat Titans
# 71        72         Lucknow Super Giants         Mumbai Indians
# 72        73               Gujarat Titans         Mumbai Indians
# 73        74               Gujarat Titans    Chennai Super Kings
#
#                                              Team  \
# 0           Gujarat Titans Vs Chennai Super Kings
# 1           Punjab Kings Vs Kolkata Knight Riders
# ...

# %%
df1 = df1.drop('Scoreboard Link', axis=1)

# %%
df1.isnull().sum()
# Out:
# Match_Id    0
# Team 1      0
# Team 2      0
# Team        0
# Winner      1
# Margin      0
# Ground      0
# Date        0
# dtype: int64

# %%
df1
# Out:
#     Match_Id                       Team 1                 Team 2  \
# 0          1               Gujarat Titans    Chennai Super Kings
# 1          2                 Punjab Kings  Kolkata Knight Riders
# 2          3         Lucknow Super Giants         Delhi Capitals
# 3          4          Sunrisers Hyderabad       Rajasthan Royals
# 4          5  Royal Challengers Bangalore         Mumbai Indians
# ..       ...                          ...                    ...
# 69        70  Royal Challengers Bangalore         Gujarat Titans
# 70        71          Chennai Super Kings         Gujarat Titans
# 71        72         Lucknow Super Giants         Mumbai Indians
# 72        73               Gujarat Titans         Mumbai Indians
# 73        74               Gujarat Titans    Chennai Super Kings
#
#                                              Team  \
# 0           Gujarat Titans Vs Chennai Super Kings
# 1           Punjab Kings Vs Kolkata Knight Riders
# ...

# %%
df1.to_csv("D:\Data Analysis\Projects\IPL2023\IPLSchedule.csv", index=False)

# %%
df2 = pd.read_csv("D:\Data Analysis\Projects\IPL2023\data\IPLBatting1.csv")

# %%
df2
# Out:
#       Match_Id                                        Team  \
# 0            1       Chennai Super Kings Vs Gujarat Titans
# 1            1       Chennai Super Kings Vs Gujarat Titans
# 2            1       Chennai Super Kings Vs Gujarat Titans
# 3            1       Chennai Super Kings Vs Gujarat Titans
# 4            1       Chennai Super Kings Vs Gujarat Titans
# ...        ...                                         ...
# 1168        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1169         3      Lucknow Super Giants Vs Delhi Capitals
# 1170        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1171        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1172        29  Sunrisers Hyderabad Vs Chennai Super Kings
#
#              Batting Team      Player Name  Player Position  \
# 0     Chennai Super Kings     Devon Conway                1
# 1     Chennai Super Kings  Ruturaj Gaikwad                2
# 2     Chennai Super Kings        Moeen Ali                3
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1173 entries, 0 to 1172
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Match_Id         1173 non-null   int64
#  1   Team             1173 non-null   object
#  2   Batting Team     1173 non-null   object
#  3   Player Name      1173 non-null   object
#  4   Player Position  1173 non-null   int64
#  5   Out              907 non-null    object
#  6   Run              1173 non-null   int64
#  7   Ball             1173 non-null   int64
#  8   Four             1173 non-null   int64
#  9   Six              1173 non-null   int64
#  10  StrikeRate       1173 non-null   float64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 100.9+ KB

# %%
df2['Out'] = df2['Out'].where(pd.notna(df2['Out']), pd.NA)
df2['Out'] = df2['Out'].fillna('')

# %%
df2
# Out:
#       Match_Id                                        Team  \
# 0            1       Chennai Super Kings Vs Gujarat Titans
# 1            1       Chennai Super Kings Vs Gujarat Titans
# 2            1       Chennai Super Kings Vs Gujarat Titans
# 3            1       Chennai Super Kings Vs Gujarat Titans
# 4            1       Chennai Super Kings Vs Gujarat Titans
# ...        ...                                         ...
# 1168        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1169         3      Lucknow Super Giants Vs Delhi Capitals
# 1170        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1171        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1172        29  Sunrisers Hyderabad Vs Chennai Super Kings
#
#              Batting Team      Player Name  Player Position  \
# 0     Chennai Super Kings     Devon Conway                1
# 1     Chennai Super Kings  Ruturaj Gaikwad                2
# 2     Chennai Super Kings        Moeen Ali                3
# ...

# %%
df2['Out/NotOut'] = df2.Out.apply(lambda x:"Out" if len(x) > 0 else "NotOut")

# %%
df2
# Out:
#       Match_Id                                        Team  \
# 0            1       Chennai Super Kings Vs Gujarat Titans
# 1            1       Chennai Super Kings Vs Gujarat Titans
# 2            1       Chennai Super Kings Vs Gujarat Titans
# 3            1       Chennai Super Kings Vs Gujarat Titans
# 4            1       Chennai Super Kings Vs Gujarat Titans
# ...        ...                                         ...
# 1168        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1169         3      Lucknow Super Giants Vs Delhi Capitals
# 1170        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1171        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1172        29  Sunrisers Hyderabad Vs Chennai Super Kings
#
#              Batting Team      Player Name  Player Position  \
# 0     Chennai Super Kings     Devon Conway                1
# 1     Chennai Super Kings  Ruturaj Gaikwad                2
# 2     Chennai Super Kings        Moeen Ali                3
# ...

# %%
df2 = df2.drop('Out', axis=1)

# %%
df2
# Out:
#       Match_Id                                        Team  \
# 0            1       Chennai Super Kings Vs Gujarat Titans
# 1            1       Chennai Super Kings Vs Gujarat Titans
# 2            1       Chennai Super Kings Vs Gujarat Titans
# 3            1       Chennai Super Kings Vs Gujarat Titans
# 4            1       Chennai Super Kings Vs Gujarat Titans
# ...        ...                                         ...
# 1168        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1169         3      Lucknow Super Giants Vs Delhi Capitals
# 1170        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1171        29  Sunrisers Hyderabad Vs Chennai Super Kings
# 1172        29  Sunrisers Hyderabad Vs Chennai Super Kings
#
#              Batting Team      Player Name  Player Position  Run  Ball  Four  \
# 0     Chennai Super Kings     Devon Conway                1    1     6     0
# 1     Chennai Super Kings  Ruturaj Gaikwad                2   92    50     4
# ...

# %%
df2 = df2.sort_values(by='Match_Id')

# %%
df2
# Out:
#      Match_Id                                   Team         Batting Team  \
# 0           1  Chennai Super Kings Vs Gujarat Titans  Chennai Super Kings
# 16          1  Chennai Super Kings Vs Gujarat Titans       Gujarat Titans
# 14          1  Chennai Super Kings Vs Gujarat Titans       Gujarat Titans
# 12          1  Chennai Super Kings Vs Gujarat Titans       Gujarat Titans
# 11          1  Chennai Super Kings Vs Gujarat Titans       Gujarat Titans
# ..        ...                                    ...                  ...
# 266        74  Gujarat Titans Vs Chennai Super Kings  Chennai Super Kings
# 293        74  Gujarat Titans Vs Chennai Super Kings  Chennai Super Kings
# 294        74  Gujarat Titans Vs Chennai Super Kings  Chennai Super Kings
# 202        74  Gujarat Titans Vs Chennai Super Kings       Gujarat Titans
# 295        74  Gujarat Titans Vs Chennai Super Kings  Chennai Super Kings
#
#          Player Name  Player Position  Run  Ball  Four  Six  StrikeRate  \
# ...

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#       Match_Id                                   Team         Batting Team  \
# 0            1  Chennai Super Kings Vs Gujarat Titans  Chennai Super Kings
# 1            1  Chennai Super Kings Vs Gujarat Titans       Gujarat Titans
# 2            1  Chennai Super Kings Vs Gujarat Titans       Gujarat Titans
# 3            1  Chennai Super Kings Vs Gujarat Titans       Gujarat Titans
# 4            1  Chennai Super Kings Vs Gujarat Titans       Gujarat Titans
# ...        ...                                    ...                  ...
# 1168        74  Gujarat Titans Vs Chennai Super Kings  Chennai Super Kings
# 1169        74  Gujarat Titans Vs Chennai Super Kings  Chennai Super Kings
# 1170        74  Gujarat Titans Vs Chennai Super Kings  Chennai Super Kings
# 1171        74  Gujarat Titans Vs Chennai Super Kings       Gujarat Titans
# 1172        74  Gujarat Titans Vs Chennai Super Kings  Chennai Super Kings
#
# ...

# %%
df2.isnull().sum()
# Out:
# Match_Id           0
# Team               0
# Batting Team       0
# Player Name        0
# Player Position    0
# Run                0
# Ball               0
# Four               0
# Six                0
# StrikeRate         0
# Out/NotOut         0
# dtype: int64

# %%
df2.to_csv("D:\Data Analysis\Projects\IPL2023\IPLBat.csv", index=False)

# %%
df3 = pd.read_csv("D:\Data Analysis\Projects\IPL2023\data\IPLBowling1.csv")

# %%
df3
# Out:
#      Match_Id                                        Team  \
# 0           1       Chennai Super Kings Vs Gujarat Titans
# 1           1       Chennai Super Kings Vs Gujarat Titans
# 2           1       Chennai Super Kings Vs Gujarat Titans
# 3           1       Chennai Super Kings Vs Gujarat Titans
# 4           1       Chennai Super Kings Vs Gujarat Titans
# ..        ...                                         ...
# 887        11          Rajasthan Royals Vs Delhi Capitals
# 888        11          Rajasthan Royals Vs Delhi Capitals
# 889        11          Rajasthan Royals Vs Delhi Capitals
# 890         4     Rajasthan Royals Vs Sunrisers Hyderabad
# 891        29  Sunrisers Hyderabad Vs Chennai Super Kings
#
#             Bowling Team       Bowler Name  Overs  Maidens  Runs  Wickets  \
# 0         Gujarat Titans    Mohammed Shami    4.0        0    29      2.0
# 1         Gujarat Titans     Hardik Pandya    3.0        0    28      NaN
# ...

# %%
df3['Wickets'].fillna(0, inplace=True)

# %%
df3
# Out:
#      Match_Id                                        Team  \
# 0           1       Chennai Super Kings Vs Gujarat Titans
# 1           1       Chennai Super Kings Vs Gujarat Titans
# 2           1       Chennai Super Kings Vs Gujarat Titans
# 3           1       Chennai Super Kings Vs Gujarat Titans
# 4           1       Chennai Super Kings Vs Gujarat Titans
# ..        ...                                         ...
# 887        11          Rajasthan Royals Vs Delhi Capitals
# 888        11          Rajasthan Royals Vs Delhi Capitals
# 889        11          Rajasthan Royals Vs Delhi Capitals
# 890         4     Rajasthan Royals Vs Sunrisers Hyderabad
# 891        29  Sunrisers Hyderabad Vs Chennai Super Kings
#
#             Bowling Team       Bowler Name  Overs  Maidens  Runs  Wickets  \
# 0         Gujarat Titans    Mohammed Shami    4.0        0    29      2.0
# 1         Gujarat Titans     Hardik Pandya    3.0        0    28      0.0
# ...

# %%
df3['Wickets'] = df3['Wickets'].astype(int)

# %%
df3.sort_values('Match_Id', inplace=True)

# %%
df3.reset_index(drop=True)
# Out:
#      Match_Id                                   Team         Bowling Team  \
# 0           1  Chennai Super Kings Vs Gujarat Titans       Gujarat Titans
# 1           1  Chennai Super Kings Vs Gujarat Titans  Chennai Super Kings
# 2           1  Chennai Super Kings Vs Gujarat Titans  Chennai Super Kings
# 3           1  Chennai Super Kings Vs Gujarat Titans  Chennai Super Kings
# 4           1  Chennai Super Kings Vs Gujarat Titans  Chennai Super Kings
# ..        ...                                    ...                  ...
# 887        74  Gujarat Titans Vs Chennai Super Kings  Chennai Super Kings
# 888        74  Gujarat Titans Vs Chennai Super Kings       Gujarat Titans
# 889        74  Gujarat Titans Vs Chennai Super Kings       Gujarat Titans
# 890        74  Gujarat Titans Vs Chennai Super Kings       Gujarat Titans
# 891        74  Gujarat Titans Vs Chennai Super Kings       Gujarat Titans
#
#                 Bowler Name  Overs  Maidens  Runs  Wickets  Economy  Zeros  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 892 entries, 0 to 193
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Match_Id      892 non-null    int64
#  1   Team          892 non-null    object
#  2   Bowling Team  892 non-null    object
#  3   Bowler Name   892 non-null    object
#  4   Overs         892 non-null    float64
#  5   Maidens       892 non-null    int64
#  6   Runs          892 non-null    int64
#  7   Wickets       892 non-null    int32
#  8   Economy       892 non-null    float64
#  9   Zeros         892 non-null    int64
#  10  Wides         892 non-null    int64
#  11  No Ball       892 non-null    int64
# dtypes: float64(2), int32(1), int64(6), object(3)
# memory usage: 87.1+ KB

# %%
df3.to_csv("D:\Data Analysis\Projects\IPL2023\IPLBall.csv", index=False)

# %%
dfs = pd.read_csv("D:\Data Analysis\Projects\IPL2023\Clean Data\Cleaned_IPL_Batting_Summary.csv")

# %%
dfs
# Out:
#       position          batsmen out_notout  runs  balls  fours  sixes      sr  \
# 0            1     Devon Conway        out     1      6      0      0   16.66
# 1            2  Ruturaj Gaikwad        out    92     50      4      9     184
# 2            3        Moeen Ali        out    23     17      4      1  135.29
# 3            4       Ben Stokes        out     7      6      1      0  116.66
# 4            5    Ambati Rayudu        out    12     12      0      1     100
# ...        ...              ...        ...   ...    ...    ...    ...     ...
# 1176         3      Shivam Dube    not out    32     21      0      2  152.38
# 1177         4   Ajinkya Rahane        out    27     13      2      2  207.69
# 1178         5    Ambati Rayudu        out    19      8      1      2   237.5
# 1179         6        MS Dhoni         out     0      1      0      0       0
# 1180         7  Ravindra Jadeja    not out    15      6      1      1     250
#
# ...

# %%
dfv = pd.read_csv("D:\Data Analysis\Projects\IPL2023\Clean Data\Cleaned_IPL_Player_Summary_With_Img.csv")

# %%
dfv
# Out:
#                 player                 role   batting_style  \
# 0             MS Dhoni  Wicketkeeper Batter  Right hand Bat
# 1          Akash Singh               Bowler  Right hand Bat
# 2            Moeen Ali   Batting Allrounder   Left hand Bat
# 3        Bhagath Varma   Bowling Allrounder  Right hand Bat
# 4        Deepak Chahar               Bowler  Right hand Bat
# ..                 ...                  ...             ...
# 257        Umran Malik               Bowler  Right hand Bat
# 258     Vivrant Sharma           Allrounder   Left hand Bat
# 259       Samarth Vyas           Allrounder  Right hand Bat
# 260      Upendra Yadav  Wicketkeeper Batter  Right hand Bat
# 261  Washington Sundar   Bowling Allrounder   Left hand Bat
#
#             bowling_style                                              Image  \
# 0        Right arm Medium  https://img1.hscicdn.com/image/upload/f_auto,t...
# 1    Left arm Medium fast  https://img1.hscicdn.com/image/upload/f_auto,t...
# ...

# %%
dff =  dfs['batsmen'].map(dfv['player'])

# %%
dff.head(50)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 42    NaN
# 43    NaN
# 44    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 49    NaN
# Name: batsmen, dtype: object
